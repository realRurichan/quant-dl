# %% [markdown]
# # 01 · Data
# Download OHLCV from Yahoo Finance with local parquet cache.

# %%
import sys; sys.path.insert(0, '../src')
import matplotlib.pyplot as plt
from quant_dl.data import download
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
TICKER = 'AAPL'
df = download(TICKER, '2018-01-01', '2025-01-01')
df.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price             open        high         low       close    volume
# Date
# 2024-12-24  253.649240  256.349629  253.450669  256.339722  23234700
# 2024-12-26  256.329802  258.226044  255.773839  257.153809  27237100
# 2024-12-27  255.972371  256.836129  251.236749  253.748520  42355300
# 2024-12-30  250.412748  251.673602  248.943415  250.382965  35557500
# 2024-12-31  250.621234  251.455179  247.632911  248.615784  39480700

# %%
df['close'].plot(title=f'{TICKER} close', figsize=(12, 4))
plt.show()
